# %%
data_1 = [
    ["Alice", 30, "London"],
    ["Bob", 25, "New York"],
    ["Carol", 27, "San Francisco"],
    ["Dave", 35, "Berlin"],
]

# %%
data_2 = [
    {"name":"Alice", "age": 30, "city": "London"},
    {"name":"Bob", "age": 25, "city": "New York"},
    {"name":"Carol", "age": 27, "city": "San Francisco"},
    {"name":"Dave", "age": 35, "city": "Berlin"},
]

# %%
Schema = "name string, age integer, city string"
spark.createDataFrame(data_1, schema=Schema).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th><th>city</th></tr></thead><tbody><tr><td>Alice</td><td>30</td><td>London</td></tr><tr><td>Bob</td><td>25</td><td>New York</td></tr><tr><td>Carol</td><td>27</td><td>San Francisco</td></tr><tr><td>Dave</td><td>35</td><td>Berlin</td></tr></tbody></table></div>

# %%
spark.createDataFrame(data_2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>city</th><th>name</th></tr></thead><tbody><tr><td>30</td><td>London</td><td>Alice</td></tr><tr><td>25</td><td>New York</td><td>Bob</td></tr><tr><td>27</td><td>San Francisco</td><td>Carol</td></tr><tr><td>35</td><td>Berlin</td><td>Dave</td></tr></tbody></table></div>
