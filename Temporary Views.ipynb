# %%
df = spark.read.table("population_metrics1.default.countries_population")

# %% [markdown]
# Local Temporary Views

# %%
#Here _sqldf is the view name. you can query this view using this name.
df.createTempView("_sqldf")

# %%
spark.sql("Select * from _sqldf").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Global Temporary Views

# %%
df.createOrReplaceGlobalTempView("_sql_gdf")

# %%
spark.sql("Select * from global_temp._sql_gdf").display()
