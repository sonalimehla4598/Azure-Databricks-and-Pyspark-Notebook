# %%
# %sql
--This cell prints a string              ------in sql to add comment we dont use # instead we use --
SELECT "Welcome to this Databricks Course!"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>"Welcome to this Databricks Course!"</th></tr></thead><tbody><tr><td>Welcome to this Databricks Course!</td></tr></tbody></table></div>

# %% [markdown]
# Now By Default the language of the Notebook is SQL, all cells have SQL language. If we want to mix language in a notebook and change the Language for a particular cell to Python we need to use the magic command at the top of the cell. This changes the language of th cell to python.. As demonstrated below.

# %%
# %python
#This cell prints a string            -----comment added using #
print("Welcome to the Databricks Course!")
# Out:
# Welcome to the Databricks Course!
